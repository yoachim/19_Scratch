# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import lsst.sims.maf.slicers as slicers
import lsst.sims.maf.metrics as metrics
import lsst.sims.maf.metricBundles as metricBundles
import lsst.sims.maf.db as db
import lsst.sims.maf.plots as plots
import healpy as hp

# %%
opsdb = db.OpsimDatabase('baseline_v1.3_10yrs.db')
outDir = 'twmp'
resultsDb = db.ResultsDb(outDir=outDir)

# %%
filternames = ['u', 'g', 'r', 'i', 'z', 'y']

bundleList = []

slicer = slicers.HealpixSlicer()
plotDict = {'colorMax': 5}
for filtername in filternames:
    sql = 'filter="%s" and night<%f' % (filtername, 365./2)
    metric = metrics.CountMetric('observationStartMJD')
    bundleList.append(metricBundles.MetricBundle(metric,slicer,sql, plotDict=plotDict))
# Out:
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes

# %%
bundleDict = metricBundles.makeBundlesDictFromList(bundleList)
bgroup = metricBundles.MetricBundleGroup(bundleDict, opsdb, outDir=outDir, resultsDb=resultsDb)
bgroup.runAll()
# Out:
# Querying database SummaryAllProps with constraint filter="r" and night<182.500000 for columns ['fieldDec', 'observationStartMJD', 'fieldRA']
# Found 25775 visits
# Running:  ['opsim_Count_observationStartMJD_r_and_nightlt182_500000_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="g" and night<182.500000 for columns ['fieldDec', 'observationStartMJD', 'fieldRA']
# Found 9913 visits
# Running:  ['opsim_Count_observationStartMJD_g_and_nightlt182_500000_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="z" and night<182.500000 for columns ['fieldDec', 'observationStartMJD', 'fieldRA']
# Found 31905 visits
# Running:  ['opsim_Count_observationStartMJD_z_and_nightlt182_500000_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="i" and night<182.500000 for columns ['fieldDec', 'observationStartMJD', 'fieldRA']
# Found 23921 visits
# Running:  ['opsim_Count_observationStartMJD_i_and_nightlt182_500000_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="y" and night<182.500000 for columns ['fieldDec', 'observationStartMJD', 'fieldRA']
# Found 27421 visits
# Running:  ['opsim_Count_observationStartMJD_y_and_nightlt182_500000_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="u" and night<182.500000 for columns ['fieldDec', 'observationStartMJD', 'fieldRA']
# Found 7575 visits
# Running:  ['opsim_Count_observationStartMJD_u_and_nightlt182_500000_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.

# %%
bgroup.plotAll(closefigs=False)
# Out:
# Plotting figures with "filter="r" and night<182.500000" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 2116 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 8.22931  dipole: lon: 113.877, lat: -30.4315, amp: 5.87265
# Plotting complete.
# Plotting figures with "filter="g" and night<182.500000" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 3037 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 3.52928  dipole: lon: 87.3455, lat: -23.4727, amp: 2.07474
# Plotting complete.
# Plotting figures with "filter="z" and night<182.500000" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 2099 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 10.2092  dipole: lon: 132.861, lat: -23.3346, amp: 7.17192
# Plotting complete.
# Plotting figures with "filter="i" and night<182.500000" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 1810 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 7.78592  dipole: lon: 124.932, lat: -29.5268, amp: 5.28318
# Plotting complete.
# Plotting figures with "filter="y" and night<182.500000" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 1234 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 12.6975  dipole: lon: 120.509, lat: 15.805, amp: 8.61135
# Plotting complete.
# Plotting figures with "filter="u" and night<182.500000" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 1288 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 3.47228  dipole: lon: 99.3609, lat: -17.6168, amp: 1.68145
# Plotting complete.
