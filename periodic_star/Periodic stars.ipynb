# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import healpy as hp

import lsst.sims.maf.db as db
import lsst.sims.maf.utils as utils
import lsst.sims.maf.metrics as metrics
import lsst.sims.maf.slicers as slicers
import lsst.sims.maf.stackers as stackers
import lsst.sims.maf.metricBundles as metricBundles

# %%
dbFile = 'baseline_v1.4_10yrs.db'
# This connection checks which version it thinks the database is and should do the right thing schema-wise
conn = db.OpsimDatabase(dbFile)
outDir='temp'
resultsDb = db.ResultsDb(outDir=outDir)

# %%
bundleList = []
sql = ''
metric = metrics.PeriodicDetectMetric()
slicer = slicers.HealpixSlicer()
plotDict = {}
bundleList.append(metricBundles.MetricBundle(metric,slicer,sql, plotDict=plotDict))
# Out:
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes

# %%
bd = metricBundles.makeBundlesDictFromList(bundleList)
bg = metricBundles.MetricBundleGroup(bd, conn, outDir=outDir, resultsDb=resultsDb)
bg.runAll()

bg.plotAll(closefigs=False)
# Out:
# Querying database SummaryAllProps with no constraint for columns ['fiveSigmaDepth', 'fieldRA', 'fieldDec', 'observationStartMJD'].
# Found 2180589 visits
# Running:  ['opsim_PeriodicDetectMetric_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:56: RuntimeWarning: divide by zero encountered in double_scalars
#   nbins = (binmax - binmin) / binwidth
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:58: UserWarning: Optimal bin calculation tried to make inf bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 0.992306  dipole: lon: 96.7036, lat: -76.2624, amp: 0.0139803
# Plotting complete.

# %%
periods=[0.1,1., 10., 50.]
amplitudes = [0.05]*len(periods)
starMags=[20.]*len(periods)
bundleList = []
sql = ''
metric = metrics.PeriodicDetectMetric(periods=periods, amplitudes=amplitudes, starMags=starMags)
slicer = slicers.HealpixSlicer()
plotDict = {}
bundleList.append(metricBundles.MetricBundle(metric,slicer,sql, plotDict=plotDict))
# Out:
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes

# %%
bd = metricBundles.makeBundlesDictFromList(bundleList)
bg = metricBundles.MetricBundleGroup(bd, conn, outDir=outDir, resultsDb=resultsDb)
bg.runAll()

bg.plotAll(closefigs=False)
# Out:
# Querying database SummaryAllProps with no constraint for columns ['fiveSigmaDepth', 'fieldRA', 'fieldDec', 'observationStartMJD'].
# Found 2180589 visits
# Running:  ['opsim_PeriodicDetectMetric_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:56: RuntimeWarning: divide by zero encountered in double_scalars
#   nbins = (binmax - binmin) / binwidth
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:58: UserWarning: Optimal bin calculation tried to make inf bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 3.93002  dipole: lon: 117.787, lat: -77.0804, amp: 0.12243
# Plotting complete.

# %%
periods=[0.1,0.1,1.,1., 10., 10., 50., 50.]
amplitudes = [0.05]*len(periods)
starMags=[20.,24.]*int((len(periods)/2))
bundleList = []
sql = 'filter="r" or filter="i" or filter="g"'
metric = metrics.PeriodicDetectMetric(periods=periods, amplitudes=amplitudes, starMags=starMags)
slicer = slicers.HealpixSlicer()
plotDict = {}
bundleList.append(metricBundles.MetricBundle(metric,slicer,sql, plotDict=plotDict))

bd = metricBundles.makeBundlesDictFromList(bundleList)
bg = metricBundles.MetricBundleGroup(bd, conn, outDir=outDir, resultsDb=resultsDb)
bg.runAll()

bg.plotAll(closefigs=False)
# Out:
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying database SummaryAllProps with constraint filter="r" or filter="i" or filter="g" for columns ['fiveSigmaDepth', 'fieldRA', 'fieldDec', 'observationStartMJD']
# Found 1163205 visits
# Running:  ['opsim_PeriodicDetectMetric_r_or_i_or_g_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "filter="r" or filter="i" or filter="g"" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:56: RuntimeWarning: divide by zero encountered in double_scalars
#   nbins = (binmax - binmin) / binwidth
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:58: UserWarning: Optimal bin calculation tried to make inf bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 3.93824  dipole: lon: 106.739, lat: -75.6554, amp: 0.111427
# Plotting complete.

# %%
periods=[0.1,0.1,1.,1., 10., 10., 50., 50.]
amplitudes = [0.05]*len(periods)
starMags=[20.,24.]*int((len(periods)/2))
bundleList = []
sql = 'filter="i"'
metric = metrics.PeriodicDetectMetric(periods=periods, amplitudes=amplitudes, starMags=starMags)
slicer = slicers.HealpixSlicer()
plotDict = {}
bundleList.append(metricBundles.MetricBundle(metric,slicer,sql, plotDict=plotDict))

bd = metricBundles.makeBundlesDictFromList(bundleList)
bg = metricBundles.MetricBundleGroup(bd, conn, outDir=outDir, resultsDb=resultsDb)
bg.runAll()

bg.plotAll(closefigs=False)
# Out:
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying database SummaryAllProps with constraint filter="i" for columns ['fiveSigmaDepth', 'fieldRA', 'fieldDec', 'observationStartMJD']
# Found 478452 visits
# Running:  ['opsim_PeriodicDetectMetric_i_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "filter="i"" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:56: RuntimeWarning: divide by zero encountered in double_scalars
#   nbins = (binmax - binmin) / binwidth
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:58: UserWarning: Optimal bin calculation tried to make inf bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 3.71264  dipole: lon: -166.241, lat: -77.3187, amp: 0.399552
# Plotting complete.
