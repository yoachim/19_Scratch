# %%
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
import healpy as hp

# %%
old = np.load('/Users/yoachim/gitRepos/sims_skybrightness_pre/data/old_percentile_m5_maps.npz')
new = np.load('/Users/yoachim/gitRepos/sims_skybrightness_pre/data/percentile_m5_maps.npz')

# %%
old.keys()
# Out:
# ['histogram_npts', 'histograms']

# %%
hp.mollview(old['histogram_npts'])
hp.mollview(new['histogram_npts'])

# %%
hp.mollview(old['histograms']['r'][18], min=22)

# %%
hp.mollview(new['histograms']['r'][18], min=22)
